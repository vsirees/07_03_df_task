# %%
# Task1: import excel  "Feb" sheet file
import pandas as pd
import numpy as np
df_Feb = pd.read_excel(r"D:\practice\Python_Practice\0703tasks\data1.xlsx", sheet_name="Feb")

# %%
df_Feb
# Out:
#     Day    Product   Sales
# 0     1      cloths     98
# 1     2      cloths     56
# 2     3      cloths     43
# 3     4      cloths      5
# 4     5      cloths      6
# 5     6      cloths     87
# 6     7      cloths     34
# 7     8      cloths     25
# 8     9      cloths     34
# 9    10      cloths     26
# 10   11      cloths      3
# 11   12      cloths      4
# 12   13    Footware      7
# 13   14    Footware     56
# 14   15    Footware      2
# 15   16    Footware      1
# 16   17    Footware      5
# 17   18    Footware      7
# 18   19    Footware     65
# 19   20    Footware     24
# 20   21    Footware     56
# 21   22    Footware     98
# 22   23    Footware    101
# 23   24  Electronic     23
# 24   25  Electronic     45
# 25   26  Electronic      6
# 26   27  Electronic     34
# 27   28  Electronic     23

# %%
# Task2 : Display basic checks
df_Feb.head()
# Out:
#    Day Product   Sales
# 0    1   cloths     98
# 1    2   cloths     56
# 2    3   cloths     43
# 3    4   cloths      5
# 4    5   cloths      6

# %%
df_Feb.tail()
# Out:
#     Day    Product   Sales
# 23   24  Electronic     23
# 24   25  Electronic     45
# 25   26  Electronic      6
# 26   27  Electronic     34
# 27   28  Electronic     23

# %%
df_Feb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28 entries, 0 to 27
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Day       28 non-null     int64
#  1   Product   28 non-null     object
#  2   Sales     28 non-null     int64
# dtypes: int64(2), object(1)
# memory usage: 800.0+ bytes

# %%
df_Feb.columns
# Out:
# Index(['Day', 'Product ', 'Sales'], dtype='object')

# %%
df_Feb.dtypes
# Out:
# Day          int64
# Product     object
# Sales        int64
# dtype: object

# %%
df_Feb.shape
# Out:
# (28, 3)

# %%
#data filters
# Task3: a> Filter only cloths data and display
df_Feb_cloths=df[df_Feb["Product "]=="cloths"]

# %%
df_Feb_cloths
# Out:
#     Day Product   Sales
# 0     1   cloths     98
# 1     2   cloths     56
# 2     3   cloths     43
# 3     4   cloths      5
# 4     5   cloths      6
# 5     6   cloths     87
# 6     7   cloths     34
# 7     8   cloths     25
# 8     9   cloths     34
# 9    10   cloths     26
# 10   11   cloths      3
# 11   12   cloths      4

# %%
# b> Filter only electronic data and display
df_Feb_Electronic=df[df_Feb["Product "]=="Electronic"]

# %%
df_Feb_Electronic
# Out:
#     Day    Product   Sales
# 23   24  Electronic     23
# 24   25  Electronic     45
# 25   26  Electronic      6
# 26   27  Electronic     34
# 27   28  Electronic     23

# %%
# c> Filter only Foot ware data and display
df_Feb_Footware=df[df_Feb["Product "]=="Footware"]

# %%
df_Feb_Footware
# Out:
#     Day  Product   Sales
# 12   13  Footware      7
# 13   14  Footware     56
# 14   15  Footware      2
# 15   16  Footware      1
# 16   17  Footware      5
# 17   18  Footware      7
# 18   19  Footware     65
# 19   20  Footware     24
# 20   21  Footware     56
# 21   22  Footware     98
# 22   23  Footware    101

# %%
# e> Filter cloths and electronic data & display

# %%
df_Feb_Elec_Footware=df[(df_Feb["Product "]=="cloths") & (df_Feb["Product "]=="Electronic")]

# %%
df_Feb_Elec_Footware
# Out:
# Empty DataFrame
# Columns: [Day, Product , Sales]
# Index: []

# %%
# Task4: import excel "Mar" and "Feb" excel sheets
# Append two dataframe
df_Mar = pd.read_excel(r"D:\practice\Python_Practice\0703tasks\data1.xlsx", sheet_name="Mar")

# %%
df_Feb_Mar=pd.concat([df_Feb,df_Mar],ignore_index=True,axis=0)

# %%
df_Feb_Mar
# Out:
#     Day    Product   Sales
# 0     1      cloths     98
# 1     2      cloths     56
# 2     3      cloths     43
# 3     4      cloths      5
# 4     5      cloths      6
# 5     6      cloths     87
# 6     7      cloths     34
# 7     8      cloths     25
# 8     9      cloths     34
# 9    10      cloths     26
# 10   11      cloths      3
# 11   12      cloths      4
# 12   13    Footware      7
# 13   14    Footware     56
# 14   15    Footware      2
# 15   16    Footware      1
# 16   17    Footware      5
# 17   18    Footware      7
# 18   19    Footware     65
# 19   20    Footware     24
# 20   21    Footware     56
# 21   22    Footware     98
# 22   23    Footware    101
# 23   24  Electronic     23
# 24   25  Electronic     45
# 25   26  Electronic      6
# 26   27  Electronic     34
# 27   28  Electronic     23
# 28    1      cloths     98
# 29    2      cloths     56
# 30    3      cloths     43
# 31    4      cloths      5
# 32    5      cloths      6
# ...

# %%
# Task: import excel "Feb" and "Mar"  sheets
# Merge two data frame by "day" and "product"

# %%
df_Feb_Mar=df_Feb.merge(df_Mar, how="inner", on=["Day", "Product "])

# %%
df_Feb_Mar
# Out:
#     Day    Product   Sales_x  Sales_y
# 0     1      cloths       98       98
# 1     2      cloths       56       56
# 2     3      cloths       43       43
# 3     4      cloths        5        5
# 4     5      cloths        6        6
# 5     6      cloths       87       87
# 6     7      cloths       34       34
# 7     8      cloths       25       25
# 8     9      cloths       34       34
# 9    10      cloths       26       26
# 10   11      cloths        3        3
# 11   12      cloths        4        4
# 12   13    Footware        7        7
# 13   14    Footware       56       56
# 14   15    Footware        2        2
# 15   16    Footware        1        1
# 16   17    Footware        5        5
# 17   18    Footware        7        7
# 18   19    Footware       65       65
# 19   20    Footware       24       24
# 20   21    Footware       56       56
# 21   22    Footware       98       98
# 22   23    Footware      101      101
# 23   24  Electronic       23       23
# ...
