# %%
import pandas as pd
import numpy as np

# %%
# importing Excel File
df_Jan = pd.read_excel(r"D:\practice\Python_Practice\0703tasks\data1.xlsx", sheet_name="Jan")

# %%
df_Jan
# Out:
#     Day    Product   Sales
# 0     1      cloths     20
# 1     2      cloths     30
# 2     3      cloths      4
# 3     4      cloths     50
# 4     5      cloths     32
# 5     6      cloths     60
# 6     7      cloths     45
# 7     8      cloths     32
# 8     9      cloths     12
# 9    10      cloths     23
# 10   11      cloths     56
# 11   12      cloths     78
# 12   13    Footware     45
# 13   14    Footware     76
# 14   15    Footware      2
# 15   16    Footware     32
# 16   17    Footware     45
# 17   18    Footware     67
# 18   19    Footware     89
# 19   20    Footware     32
# 20   21    Footware      4
# 21   22    Footware      6
# 22   23    Footware      8
# 23   24  Electronic     98
# 24   25  Electronic     76
# 25   26  Electronic     45
# 26   27  Electronic     32
# 27   28  Electronic     43
# 28   29  Electronic     21
# 29   30  Electronic     12

# %%
#basic checks
df_Jan.head()
# Out:
#    Day Product   Sales
# 0    1   cloths     20
# 1    2   cloths     30
# 2    3   cloths      4
# 3    4   cloths     50
# 4    5   cloths     32

# %%
df_Jan.tail()
# Out:
#     Day    Product   Sales
# 25   26  Electronic     45
# 26   27  Electronic     32
# 27   28  Electronic     43
# 28   29  Electronic     21
# 29   30  Electronic     12

# %%
df_Jan.shape
# Out:
# (30, 3)

# %%
df_Jan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Day       30 non-null     int64
#  1   Product   30 non-null     object
#  2   Sales     30 non-null     int64
# dtypes: int64(2), object(1)
# memory usage: 848.0+ bytes

# %%
df_Jan.columns
# Out:
# Index(['Day', 'Product ', 'Sales'], dtype='object')

# %%
df_Jan.dtypes
# Out:
# Day          int64
# Product     object
# Sales        int64
# dtype: object

# %%
#data filters 
# a> Filter only cloths data and display
df1=df[df_Jan["Product "]=="cloths"]
# Out:
# C:\Users\siriv\AppData\Local\Temp\ipykernel_9048\1336220061.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df1=df[df_Jan["Product "]=="cloths"]

# %%
df1
# Out:
#     Day Product   Sales
# 0     1   cloths     98
# 1     2   cloths     56
# 2     3   cloths     43
# 3     4   cloths      5
# 4     5   cloths      6
# 5     6   cloths     87
# 6     7   cloths     34
# 7     8   cloths     25
# 8     9   cloths     34
# 9    10   cloths     26
# 10   11   cloths      3
# 11   12   cloths      4

# %%
# b> Filter only electronic data and display
df2=df[df_Jan["Product "]=="Electronic"]
# Out:
# C:\Users\siriv\AppData\Local\Temp\ipykernel_9048\394738648.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df2=df[df_Jan["Product "]=="Electronic"]

# %%
df2
# Out:
#     Day    Product   Sales
# 23   24  Electronic     23
# 24   25  Electronic     45
# 25   26  Electronic      6
# 26   27  Electronic     34
# 27   28  Electronic     23

# %%
# c> Filter only Foot ware data and display
df3=df[df_Jan["Product "]=="Footware"]
# Out:
# C:\Users\siriv\AppData\Local\Temp\ipykernel_9048\3727436019.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df3=df[df_Jan["Product "]=="Footware"]

# %%
df3
# Out:
#     Day  Product   Sales
# 12   13  Footware      7
# 13   14  Footware     56
# 14   15  Footware      2
# 15   16  Footware      1
# 16   17  Footware      5
# 17   18  Footware      7
# 18   19  Footware     65
# 19   20  Footware     24
# 20   21  Footware     56
# 21   22  Footware     98
# 22   23  Footware    101

# %%
#e> Filter cloths and electronic data & display
df4=df[(df_Jan["Product "]=="cloths") & (df_Jan["Product "]=="Electronic")]
# Out:
# C:\Users\siriv\AppData\Local\Temp\ipykernel_9048\4223546611.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df4=df[(df_Jan["Product "]=="cloths") & (df_Jan["Product "]=="Electronic")]

# %%
df4
# Out:
# Empty DataFrame
# Columns: [Day, Product , Sales]
# Index: []

# %%
# Task4: import excel "Jan" and "Feb"  sheets
df_Feb = pd.read_excel(r"D:\practice\Python_Practice\0703tasks\data1.xlsx", sheet_name="Feb")

# %%
df_Feb
# Out:
#     Day    Product   Sales
# 0     1      cloths     98
# 1     2      cloths     56
# 2     3      cloths     43
# 3     4      cloths      5
# 4     5      cloths      6
# 5     6      cloths     87
# 6     7      cloths     34
# 7     8      cloths     25
# 8     9      cloths     34
# 9    10      cloths     26
# 10   11      cloths      3
# 11   12      cloths      4
# 12   13    Footware      7
# 13   14    Footware     56
# 14   15    Footware      2
# 15   16    Footware      1
# 16   17    Footware      5
# 17   18    Footware      7
# 18   19    Footware     65
# 19   20    Footware     24
# 20   21    Footware     56
# 21   22    Footware     98
# 22   23    Footware    101
# 23   24  Electronic     23
# 24   25  Electronic     45
# 25   26  Electronic      6
# 26   27  Electronic     34
# 27   28  Electronic     23

# %%
# Append two dataframe
df_Jan_Feb=pd.concat([df,df_Feb],ignore_index=True,axis=0)

# %%
df_Jan_Feb
# Out:
#     Day    Product   Sales
# 0     1      cloths     98
# 1     2      cloths     56
# 2     3      cloths     43
# 3     4      cloths      5
# 4     5      cloths      6
# 5     6      cloths     87
# 6     7      cloths     34
# 7     8      cloths     25
# 8     9      cloths     34
# 9    10      cloths     26
# 10   11      cloths      3
# 11   12      cloths      4
# 12   13    Footware      7
# 13   14    Footware     56
# 14   15    Footware      2
# 15   16    Footware      1
# 16   17    Footware      5
# 17   18    Footware      7
# 18   19    Footware     65
# 19   20    Footware     24
# 20   21    Footware     56
# 21   22    Footware     98
# 22   23    Footware    101
# 23   24  Electronic     23
# 24   25  Electronic     45
# 25   26  Electronic      6
# 26   27  Electronic     34
# 27   28  Electronic     23
# 28    1      cloths     98
# 29    2      cloths     56
# 30    3      cloths     43
# 31    4      cloths      5
# 32    5      cloths      6
# ...

# %%
# import excel "Jan" and "Mar"  sheets
df_Mar = pd.read_excel(r"D:\practice\Python_Practice\0703tasks\data1.xlsx", sheet_name="Mar")

# %%
df_Mar
# Out:
#     Day    Product   Sales
# 0     1      cloths     98
# 1     2      cloths     56
# 2     3      cloths     43
# 3     4      cloths      5
# 4     5      cloths      6
# 5     6      cloths     87
# 6     7      cloths     34
# 7     8      cloths     25
# 8     9      cloths     34
# 9    10      cloths     26
# 10   11      cloths      3
# 11   12      cloths      4
# 12   13    Footware      7
# 13   14    Footware     56
# 14   15    Footware      2
# 15   16    Footware      1
# 16   17    Footware      5
# 17   18    Footware      7
# 18   19    Footware     65
# 19   20    Footware     24
# 20   21    Footware     56
# 21   22    Footware     98
# 22   23    Footware    101
# 23   24  Electronic     23
# 24   25  Electronic     45
# 25   26  Electronic      6
# 26   27  Electronic     34
# 27   28  Electronic     23
# 28   29  Electronic     43
# 29   30  Electronic     54

# %%
df_Mar.columns
# Out:
# Index(['Day', 'Product ', 'Sales'], dtype='object')

# %%
# Merge two data frame by "day" and "product"

# %%
df_Jan_Mar=df.merge(df_Mar, how="inner", on=["Day", "Product "])

# %%
df_Jan_Mar
# Out:
#     Day    Product   Sales_x  Sales_y
# 0     1      cloths       98       98
# 1     2      cloths       56       56
# 2     3      cloths       43       43
# 3     4      cloths        5        5
# 4     5      cloths        6        6
# 5     6      cloths       87       87
# 6     7      cloths       34       34
# 7     8      cloths       25       25
# 8     9      cloths       34       34
# 9    10      cloths       26       26
# 10   11      cloths        3        3
# 11   12      cloths        4        4
# 12   13    Footware        7        7
# 13   14    Footware       56       56
# 14   15    Footware        2        2
# 15   16    Footware        1        1
# 16   17    Footware        5        5
# 17   18    Footware        7        7
# 18   19    Footware       65       65
# 19   20    Footware       24       24
# 20   21    Footware       56       56
# 21   22    Footware       98       98
# 22   23    Footware      101      101
# 23   24  Electronic       23       23
# ...
